# %% [markdown]
# <a href="https://colab.research.google.com/github/normannexo/ai_notebooks/blob/main/NLP_with_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Natural Language Processing with Transformers
#
# ## Text Classification

# %%
from huggingface_hub import list_datasets

all_datasets = list(list_datasets())
print(f"There are {len(all_datasets)} datasets currently available on the Hub")
print(f"The first 10 are: {all_datasets[:10]}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_2414/632435811.py in <cell line: 0>()
#       2
# ----> 3 all_datasets = list(list_datasets())
#       4 print(f"There are {len(all_datasets)} datasets currently available on the Hub")
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py in list_datasets(self, filter, author, benchmark, dataset_name, gated, language_creators, language, multilinguality, size_categories, task_categories, task_ids, search, sort, direction, limit, expand, full, token)
#    2489             items = islice(items, limit)  # Do not iterate over all pages
# -> 2490         for item in items:
#    2491             if "siblings" not in item:
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_pagination.py in paginate(path, params, headers)
# ...

# %%
from datasets import load_dataset

emotions = load_dataset("emotion")
emotions
# Out:
# README.md: 0.00B [00:00, ?B/s]
# split/train-00000-of-00001.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# split/validation-00000-of-00001.parquet:   0%|          | 0.00/127k [00:00<?, ?B/s]
# split/test-00000-of-00001.parquet:   0%|          | 0.00/129k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %%
train_ds = emotions["train"]
train_ds[:5]
# Out:
# {'text': ['i didnt feel humiliated',
#   'i can go from feeling so hopeless to so damned hopeful just from being around someone who cares and is awake',
#   'im grabbing a minute to post i feel greedy wrong',
#   'i am ever feeling nostalgic about the fireplace i will know that it is still on the property',
#   'i am feeling grouchy'],
#  'label': [0, 0, 3, 2, 3]}

# %%
train_ds.features
# Out:
# {'text': Value('string'),
#  'label': ClassLabel(names=['sadness', 'joy', 'love', 'anger', 'fear', 'surprise'])}

# %%
from huggingface_hub import login

login()

# %%
# !pip install -q huggingface_hub
